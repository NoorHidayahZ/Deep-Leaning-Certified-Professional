# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from envs import Maze
from IPython import display

# %%
# instance of the Maze class which is inside the envs.py file
env = Maze()

# %%
def show_board():
    frame = env.render(mode='rgb_array')
    plt.axis('off')
    plt.title(f"State: {initial_state}")
    plt.imshow(frame)

# %%
# let us start interacting with environment
initial_state = env.reset()

# %%
show_board()

# %%
action = 2
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (1, 0) Reward: -1.0 Done: False

# %%
action = 2
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (2, 0) Reward: -1.0 Done: False

# %%
action = 2
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (3, 0) Reward: -1.0 Done: False

# %%
action = 2
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (4, 0) Reward: -1.0 Done: False

# %%
action = 1
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (4, 1) Reward: -1.0 Done: False

# %%
action = 1
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (4, 2) Reward: -1.0 Done: False

# %%
action = 0
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (3, 2) Reward: -1.0 Done: False

# %%
action = 1
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (3, 3) Reward: -1.0 Done: False

# %%
action = 1
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (3, 4) Reward: -1.0 Done: False

# %%
action = 2
next_state, reward, done, info = env.step(action)
show_board()
print("Current State:", next_state, "Reward:", reward, "Done:", done)
# Out:
# Current State: (4, 4) Reward: -1.0 Done: True

# %%
env.reset()
done = False
img = plt.imshow(env.render(mode='rgb_array'))

# %%
def random_policy():
    return np.array([0.25] * 4)

# %%
action_probabilities = random_policy()

# %%
env.reset()
done = False
img = plt.imshow(env.render(mode='rgb_array'))
while not done:
    action = np.random.choice([0, 1, 2, 3], 1, p=action_probabilities)
    next_state, reward, done, info = env.step(action)
    img.set_data(env.render(mode='rgb_array'))
    plt.axis('off')
    display.display(plt.gcf())
    display.clear_output(wait=True)
env.close()
